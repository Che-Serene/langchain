# %% [markdown]
# ![Screenshot from 2025-11-04 10-51-09.png](준비.png)

# %%
cd ollama-ipex-llm-2.3.0b20250725-ubuntu/    
source start-ollama.sh    
./ollama run exaone3.5:7.8b
# Out:
#   Cell In[19], line 1
#     cd ollama-ipex-llm-2.3.0b20250725-ubuntu/
#                            ^
# SyntaxError: invalid decimal literal

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatOllama(model='exaone3.5:7.8b', temperature=0.7)

prompt = ChatPromptTemplate.from_messages([
    ('system', 'you are a helpful assistance'),
    ('user', "{input}")
])

output_parser = StrOutputParser()

chain = prompt | llm | output_parser

# %%
question = "중국의 수도는 어디인가요?"
response = chain.invoke({'input': question})

# %%
response
# Out:
# '중국의 수도는 **베이징**입니다.'
